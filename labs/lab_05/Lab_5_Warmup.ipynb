# %%
import pandas as pd

# %%
df = pd.read_csv('data/lab5warmupdata.txt', delimiter='\t')

# %%
df.head()
# Out:
#   number1  number2
# 0   0,589  '0,589'
# 1   0,578  '0,578'
# 2   7,779  '7,779'
# 3   0,139  '0,139'
# 4   1,687  '1,687'

# %% [markdown]
# ####Exercise 1: Strip the extra comma from the number1 column and convert to integer

# %%
#Your code here
df['number1'] = df['number1'].map(lambda x : x.replace(',','')).astype('int')
df
# Out:
# 0      589
# 1      578
# 2     7779
# 3      139
# 4     1687
# 5     3246
# 6      254
# 7     3133
# 8     9446
# 9     6241
# 10    4922
# 11    4657
# 12    5134
# 13    4947
# 14    5988
# 15    1376
# 16     291
# 17    1515
# 18    3126
# 19     853
# 20    2768
# 21    6738
# 22    8168
# 23     181
# 24    6760
# 25    2199
# 26    2207
# 27    5145
# 28    8247
# 29    7646
# 30     941
# 31    1886
# 32    4981
# 33    2140
# 34    6987
# 35     326
# 36    2867
# 37    4890
# 38    8625
# 39    4475
# 40     903
# Name: number1, dtype: int64

# %%
df
# Out:
#     number1  number2
# 0       589  '0,589'
# 1       578  '0,578'
# 2      7779  '7,779'
# 3       139  '0,139'
# 4      1687  '1,687'
# 5      3246  '3,246'
# 6       254  '0,254'
# 7      3133  '3,133'
# 8      9446  '9,446'
# 9      6241  '6,241'
# 10     4922  '4,922'
# 11     4657  '4,657'
# 12     5134  '5,134'
# 13     4947  '4,947'
# 14     5988  '5,988'
# 15     1376  '1,376'
# 16      291  '0,291'
# 17     1515  '1,515'
# 18     3126  '3,126'
# 19      853  '0,853'
# 20     2768  '2,768'
# 21     6738  '6,738'
# 22     8168  '8,168'
# 23      181  '0,181'
# 24     6760  '6,760'
# 25     2199  '2,199'
# 26     2207  '2,207'
# 27     5145  '5,145'
# 28     8247  '8,247'
# 29     7646  '7,646'
# 30      941  '0,941'
# 31     1886  '1,886'
# 32     4981  '4,981'
# 33     2140  '2,140'
# 34     6987  '6,987'
# 35      326  '0,326'
# 36     2867  '2,867'
# 37     4890  '4,890'
# 38     8625  '8,625'
# 39     4475  '4,475'
# 40      903  '0,903'

# %%
#Bonus: Do it a different way

# %% [markdown]
# ####Exercise 2: Strip the extra quotation marks from the column2 and convert to integer

# %%
#Your code here
df.number2.str[1:-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-32c5bb04445d> in <module>()
#       1 #Your code here
# ----> 2 df['number2'] = df['number2'].astype('int')
#       3
#       4
#       5
#
# /Users/raymondma/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2516
#    2517         mgr = self._data.astype(
# -> 2518             dtype=dtype, copy=copy, raise_on_error=raise_on_error, **kwargs)
#    2519         return self._constructor(mgr).__finalize__(self)
#    2520
#
# /Users/raymondma/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    2753
#    2754     def astype(self, dtype, **kwargs):
# -> 2755         return self.apply('astype', dtype=dtype, **kwargs)
#    2756
#    2757     def convert(self, **kwargs):
#
# ...
